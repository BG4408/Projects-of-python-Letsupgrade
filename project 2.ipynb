# %%
import random
import string
choice = list(string.ascii_uppercase)
movies = ['Interstellar',"Gladiator", 'Inception',"Whiplash", 'Megamind', 'Creed', 'Southpaw',"Fight Club","Rush Hour","Warrior", "Pacific Rim","Pulp Fiction","Shawshank Redemption"]

def check(qn):
    return "*" in qn
def create_question(movie):
    n = len(movie)
    letters = list(movie)
    temp = []
    for i in range(0, n):
        if letters[i] == " ":
            temp.append(" ")
        else:
            temp.append("*")
    qn = "".join(str(x) for x in temp)
    return qn


def is_present(letter, movie):
    return letter in movie


def unlock(qn, movie, letter):
    ref = list(movie)
    ql = list(qn)
    temp = []
    n = len(movie)
    for i in range(n):
        if ref[i] == letter or ref[i] == ' ':
            temp.append(ref[i])
        else:
            temp.append(ql[i])
    qn = "".join(x for x in temp)
    return qn


def play():
    picked_movie = random.choice(movies)
    picked_movie = picked_movie.upper()
    qn = create_question(picked_movie)
    print(qn)
    modified_qn = qn
    not_said = True
    while not_said:
        letter = random.choice(choice)
        choice.remove(letter)
        print("Please enter a letter :",letter)
        if is_present(letter, picked_movie):
            modified_qn = unlock(modified_qn, picked_movie, letter)
            print("Good going!",letter,"has been found in the Movie Name.")
            print()
            print(modified_qn)
            if not(check(modified_qn)):
                print("Well Done! You have guessed the Movie Name correctly!")
                not_said = False
        else:
            print(letter,"is not found in the Movie Name. Please try again!")
            print()


play()
print("\n\nTHANK YOU SO MUCH FOR TRYING THIS GAME! Comment down your favourite movie so that I can add that movie to the movie list. Have a good day :)")
# Out:
# ********
# Please enter a letter : T
# T is not found in the Movie Name. Please try again!
#
# Please enter a letter : U
# U is not found in the Movie Name. Please try again!
#
# Please enter a letter : E
# Good going! E has been found in the Movie Name.
#
# *E******
# Please enter a letter : M
# Good going! M has been found in the Movie Name.
#
# ME**M***
# Please enter a letter : B
# B is not found in the Movie Name. Please try again!
#
# Please enter a letter : Q
# Q is not found in the Movie Name. Please try again!
#
# Please enter a letter : V
# V is not found in the Movie Name. Please try again!
#
# Please enter a letter : G
# Good going! G has been found in the Movie Name.
#
# MEG*M***
# Please enter a letter : J
# J is not found in the Movie Name. Please try again!
#
# Please enter a letter : S
# S is not found in the Movie Name. Please try again!
#
# Please enter a letter : A
# Good going! A has been found in the Movie Name.
#
# MEGAM***
# Please enter a letter : N
# Good going! N has been found in the Movie Name.
#
# MEGAM*N*
# Please enter a letter : P
# P is not found in the Movie Name. Please try again!
#
# Please enter a letter : D
# Good going! D has been found in the Movie Name.
#
# MEGAM*ND
# Please enter a letter : X
# X is not found in the Movie Name. Please try again!
#
# Please enter a letter : Y
# Y is not found in the Movie Name. Please try again!
#
# Please enter a letter : Z
# Z is not found in the Movie Name. Please try again!
#
# Please enter a letter : W
# W is not found in the Movie Name. Please try again!
#
# Please enter a letter : O
# O is not found in the Movie Name. Please try again!
#
# Please enter a letter : F
# F is not found in the Movie Name. Please try again!
#
# Please enter a letter : C
# C is not found in the Movie Name. Please try again!
#
# Please enter a letter : K
# K is not found in the Movie Name. Please try again!
#
# Please enter a letter : H
# H is not found in the Movie Name. Please try again!
#
# Please enter a letter : I
# Good going! I has been found in the Movie Name.
#
# MEGAMIND
# Well Done! You have guessed the Movie Name correctly!
#
#
# THANK YOU SO MUCH FOR TRYING THIS GAME! Comment down your favourite movie so that I can add that movie to the movie list. Have a good day :)
